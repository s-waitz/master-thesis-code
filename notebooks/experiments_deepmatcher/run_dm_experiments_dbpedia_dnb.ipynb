# %%
#!pip install deepmatcher
# !pip install --upgrade --force-reinstall -e git+https://github.com/s-waitz/deepmatcher.git@master#egg=deepmatcher

# %% [markdown]
# # AL: Initialize with random sample (500)

# %%
results = run_al(dataset='dbpedia_dnb',
       num_runs=3,
       al_iterations=20,
       sampling_size=100,
       init_random_sample=20,
       epochs=20,
       batch_size=20,
       attr_summarizer='rnn',
       split_validation=True,
       save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/deepmatcher/',
       data_augmentation=False,
       high_conf_to_ls=False,
       keep_model=True,
       file_path='/content/drive/My Drive/Master Thesis/data/author/',
       embeddings_cache_path='/content/drive/My Drive/Master Thesis/embeddings',
       ignore_columns=('source_id','target_id'))

# %%
results

# %% [markdown]
# # AL: Initialize with TL without DA

# %%
results = run_al(dataset='dbpedia_dnb',
       num_runs=3,
       al_iterations=20,
       sampling_size=100,
       epochs=20,
       batch_size=20,
       split_validation=True,
       attr_summarizer='rnn',
       save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/deepmatcher/',
       transfer_learning_dataset='dbpedia_viaf',
       data_augmentation=False,
       high_conf_to_ls=False,
       keep_model=True,
       file_path='/content/drive/My Drive/Master Thesis/data/author/',
       embeddings_cache_path='/content/drive/My Drive/Master Thesis/embeddings',
       ignore_columns=('source_id','target_id','left_work','right_work'))

# %%
results

# %% [markdown]
# # AL: Initialize with TL with DA

# %%
results = run_al(dataset='dbpedia_dnb',
       num_runs=3,
       al_iterations=20,
       sampling_size=100,
       epochs=20,
       batch_size=20,
       split_validation=True,
       attr_summarizer='rnn',
       save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/deepmatcher/',
       transfer_learning_dataset='dbpedia_viaf',
       data_augmentation=True,
       high_conf_to_ls=False,
       keep_model=True,
       file_path='/content/drive/My Drive/Master Thesis/data/author/',
       embeddings_cache_path='/content/drive/My Drive/Master Thesis/embeddings',
       ignore_columns=('source_id','target_id','left_work','right_work'))

# %%
results

# %% [markdown]
# # AL: Incorporate TL Data into AL

# %%
results = run_al(dataset='dbpedia_dnb',
       num_runs=3,
       al_iterations=20,
       sampling_size=100,
       epochs=20,
       batch_size=20,
       split_validation=True,
       transfer_learning_dataset='dbpedia_viaf',
       include_tl_data=True,
       tl_weights='calc',
       attr_summarizer='rnn',
       save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/deepmatcher/',
       data_augmentation=False,
       high_conf_to_ls=False,
       keep_model=True,
       file_path='/content/drive/My Drive/Master Thesis/data/author/',
       embeddings_cache_path='/content/drive/My Drive/Master Thesis/embeddings',
       ignore_columns=('source_id','target_id','left_work','right_work'))

# %%
results
