# %%
! pip install -r requirements.txt
! python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip uninstall apex
# %cd apex
# !rm -rf build (if it exists)
# !python setup.py install --cuda_ext --cpp_ext

# %% [markdown]
# # Passive Learning

# %%
for _ in range(3):
  run_pl_ditto(task='dbpedia_viaf',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='general',
                su=False,
                balance=False,
                verbose=True)

# %%
for _ in range(3):
  run_pl_ditto(task='dbpedia_dnb',
                  save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                  base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                  ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                  train_size=None,
                  learning_model='roberta',
                  input_path='input/',
                  output_path='output/',
                  batch_size=32,
                  epochs=20,
                  da='span_del',
                  dk='general',
                  su=False,
                  balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='abt_buy',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_shuffle',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='amazon_google',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='wdc_headphones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='wdc_phones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='watches',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='cameras',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=None,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %% [markdown]
# # Passive Learning on Random Sample

# %%
for _ in range(3):
  run_pl_ditto(task='dbpedia_viaf',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                train_size=2000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='general',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='dbpedia_viaf',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                train_size=1000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='general',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='dbpedia_dnb',
                  save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                  base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                  ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                  train_size=2000,
                  learning_model='roberta',
                  input_path='input/',
                  output_path='output/',
                  batch_size=32,
                  epochs=20,
                  da='span_del',
                  dk='general',
                  su=False,
                  balance=False)
for _ in range(3):
  run_pl_ditto(task='dbpedia_dnb',
                  save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                  base_data_path='/content/drive/My Drive/Master Thesis/data/author/',
                  ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/author/',
                  train_size=1000,
                  learning_model='roberta',
                  input_path='input/',
                  output_path='output/',
                  batch_size=32,
                  epochs=20,
                  da='span_del',
                  dk='general',
                  su=False,
                  balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='abt_buy',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=2000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_shuffle',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='abt_buy',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=1000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_shuffle',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='amazon_google',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=2000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='amazon_google',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                train_size=1000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=50,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='wdc_headphones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=200,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='wdc_headphones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=100,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='wdc_phones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=200,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='wdc_phones',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                train_size=100,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=80,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='watches',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=2000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='watches',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=1000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)

# %%
for _ in range(3):
  run_pl_ditto(task='cameras',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=2000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
for _ in range(3):
  run_pl_ditto(task='cameras',
                save_results_file='/content/drive/My Drive/Master Thesis/results/ditto/pl_results.csv',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc/',
                ditto_data_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc/',
                train_size=1000,
                learning_model='roberta',
                input_path='input/',
                output_path='output/',
                batch_size=32,
                epochs=20,
                da='span_del',
                dk='product',
                su=False,
                balance=False)
