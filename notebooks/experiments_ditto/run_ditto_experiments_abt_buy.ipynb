# %%
! pip install -r requirements.txt
! python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip uninstall apex
# %cd apex
# !rm -rf build (if it exists)
# !python setup.py install --cuda_ext --cpp_ext

# %% [markdown]
# # AL: Initialize with random sample (500)

# %%
results_al = run_al_ditto(task='abt_buy',
                num_runs=3,
                al_iterations=20,
                sampling_size=100,
                epochs=60,
                epochs_tl=60,
                batch_size=20,
                reduce_epochs=[1000,50],
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                init_random_sample=100,
                data_augmentation=False,
                high_conf_to_ls=False,
                da='span_shuffle',
                dk='product',
                keep_model=False,
                su=False,
                balance=True,
                verbose=True)

# %%
results_al

# %% [markdown]
# # AL: Initialize with TL without DA

# %%
results_al = run_al_ditto(task='abt_buy',
                num_runs=3,
                al_iterations=20,
                sampling_size=100,
                epochs=60,
                epochs_tl=60,
                reduce_epochs=[1000,50],
                batch_size=20,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                transfer_learning_dataset='amazon_google',
                data_augmentation=False,
                high_conf_to_ls=False,
                da='span_shuffle',
                dk='product',
                keep_model=False,
                su=False,
                balance=True,
                verbose=True)

# %%
results_al

# %% [markdown]
# # AL: Initialize with TL with DA

# %%
results_al = run_al_ditto(task='abt_buy',
                num_runs=3,
                al_iterations=20,
                sampling_size=100,
                epochs=60,
                epochs_tl=60,
                batch_size=20,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                transfer_learning_dataset='amazon_google',
                data_augmentation=True,
                high_conf_to_ls=False,
                da='span_shuffle',
                dk='product',
                su=False,
                balance=True)

# %%
results_al

# %% [markdown]
# # AL: Initialize with TL with Weights

# %%
results_al = run_al_ditto(task='abt_buy',
                num_runs=3,
                al_iterations=20,
                sampling_size=100,
                epochs=20,
                epochs_tl=60,
                batch_size=20,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/final_experiments/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/products/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/products/',
                transfer_learning_dataset='amazon_google',
                include_tl_data=True,
                tl_weights='calc',
                data_augmentation=False,
                high_conf_to_ls=False,
                da=False,
                dk='product',
                su=False,
                balance=False,
                keep_model=False,
                verbose=True)

# %%
results_al
