# %%
! pip install -r requirements.txt
! python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip uninstall apex
# %cd apex
# !rm -rf build (if it exists)
# !python setup.py install --cuda_ext --cpp_ext

# %% [markdown]
# # AL: Initialize with random sample (500)

# %%
results_al = run_al_ditto(task='wdc_phones',
                num_runs=3,
                al_iterations=50,
                sampling_size=20,
                epochs=40,
                batch_size=32,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                init_random_sample=500,
                data_augmentation=False,
                high_conf_to_ls=False,
                da='del',
                dk=True,
                su=False,
                balance=True)

# %%
results_al

# %% [markdown]
# # AL: Initialize with TL without DA

# %%
results_al = run_al_ditto(task='wdc_phones',
                num_runs=3,
                al_iterations=50,
                sampling_size=20,
                epochs=40,
                batch_size=32,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                transfer_learning_dataset='wdc_headphones',
                data_augmentation=False,
                high_conf_to_ls=False,
                da='del',
                dk=True,
                su=False,
                balance=True)

# %%
results_al

# %% [markdown]
# # AL: Initialize with TL with DA

# %%
results_al = run_al_ditto(task='wdc_phones',
                num_runs=3,
                al_iterations=50,
                sampling_size=20,
                epochs=40,
                batch_size=32,
                learning_model='roberta',
                save_results_path='/content/drive/My Drive/Master Thesis/results/ditto/',
                base_data_path='/content/drive/My Drive/Master Thesis/data/wdc_product/',
                labeled_set_path='/content/drive/My Drive/Master Thesis/ditto/data/wdc_product/',
                transfer_learning_dataset='wdc_headphones',
                data_augmentation=True,
                high_conf_to_ls=False,
                da='del',
                dk=True,
                su=False,
                balance=True)

# %%
results_al
