# %%
import pandas as pd 
import numpy as np
import os
import sys
os.chdir("E:\\2_Studium\\1_Mannheim\\4_Semester\\Masterarbeit\\code\\master-thesis-code\\results\\final\\deepmatcher")

# %%
""" files=['deepmatcher_2source/dbpedia_dnb/al_tl_dbpedia_dnb.csv',
    'deepmatcher_2source/dbpedia_dnb/al_tl_da_dbpedia_dnb.csv',
    'deepmatcher_2source/dbpedia_viaf/al_random_init_dbpedia_viaf.csv',
    'deepmatcher_2source/dbpedia_viaf/al_tl_dbpedia_viaf.csv',
    'deepmatcher_2source/dbpedia_viaf/al_tl_da_dbpedia_viaf.csv',
    'deepmatcher_2source/dbpedia_viaf/al_tl_da_thresh_dbpedia_viaf.csv',
    'deepmatcher_2source/dbpedia_viaf/al_tl_da_to_ls_dbpedia_viaf.csv',
    'deepmatcher_2source/dbpedia_viaf/al_random_init_dbpedia_viaf.csv',
    'deepmatcher_2source/abt_buy/al_tl_abt_buy.csv',
    'deepmatcher_2source/abt_buy/al_tl_da_abt_buy.csv',
    'deepmatcher_2source/abt_buy/al_tl_da_thresh_abt_buy.csv',
    'deepmatcher_2source/abt_buy/al_tl_da_to_ls_abt_buy.csv',] """
files=['wdc_cameras/al_tl_include_source_wdc_cameras.csv']
#files=['baselines.csv']

# %%
for filename in files:
    try:
        file = pd.read_csv(filename, sep=',')
        file['F1 Mean']=file[['Run 1: f1','Run 2: f1','Run 3: f1']].mean(axis=1).round(3)
        file['F1 Std']=file[['Run 1: f1','Run 2: f1','Run 3: f1']].std(axis=1).round(3)
        file['Precision Mean']=file[['Run 1: precision','Run 2: precision','Run 3: precision']].mean(axis=1).round(3)
        file['Precision Std']=file[['Run 1: precision','Run 2: precision','Run 3: precision']].std(axis=1).round(3)
        file['Recall Mean']=file[['Run 1: recall','Run 2: recall','Run 3: recall']].mean(axis=1).round(3)
        file['Recall Std']=file[['Run 1: recall','Run 2: recall','Run 3: recall']].std(axis=1).round(3)
    except:
        file = pd.read_csv(filename, sep=';')
        file['F1 Mean']=file[['Run 1: f1','Run 2: f1','Run 3: f1']].mean(axis=1).round(3)
        file['F1 Std']=file[['Run 1: f1','Run 2: f1','Run 3: f1']].std(axis=1).round(3)
        file['Precision Mean']=file[['Run 1: precision','Run 2: precision','Run 3: precision']].mean(axis=1).round(3)
        file['Precision Std']=file[['Run 1: precision','Run 2: precision','Run 3: precision']].std(axis=1).round(3)
        file['Recall Mean']=file[['Run 1: recall','Run 2: recall','Run 3: recall']].mean(axis=1).round(3)
        file['Recall Std']=file[['Run 1: recall','Run 2: recall','Run 3: recall']].std(axis=1).round(3)
    # F1 Mean	F1 Std	Precision Mean	Precision Std	Recall Mean	Recall Std

    #print(file.columns)
    file.to_csv(filename,index=False)

# %%
for filename in files:
    try:
        file = pd.read_csv(filename, sep=';')
        file['F1 Mean']=file[['Run 1: f1','Run 2: f1']].mean(axis=1).round(3)
        file['F1 Std']=file[['Run 1: f1','Run 2: f1']].std(axis=1).round(3)
        file['Precision Mean']=file[['Run 1: precision','Run 2: precision']].mean(axis=1).round(3)
        file['Precision Std']=file[['Run 1: precision','Run 2: precision']].std(axis=1).round(3)
        file['Recall Mean']=file[['Run 1: recall','Run 2: recall']].mean(axis=1).round(3)
        file['Recall Std']=file[['Run 1: recall','Run 2: recall']].std(axis=1).round(3)
    except:
        file = pd.read_csv(filename, sep=',')
        file['F1 Mean']=file[['Run 1: f1','Run 2: f1']].mean(axis=1).round(3)
        file['F1 Std']=file[['Run 1: f1','Run 2: f1']].std(axis=1).round(3)
        file['Precision Mean']=file[['Run 1: precision','Run 2: precision']].mean(axis=1).round(3)
        file['Precision Std']=file[['Run 1: precision','Run 2: precision']].std(axis=1).round(3)
        file['Recall Mean']=file[['Run 1: recall','Run 2: recall']].mean(axis=1).round(3)
        file['Recall Std']=file[['Run 1: recall','Run 2: recall']].std(axis=1).round(3)
    # F1 Mean	F1 Std	Precision Mean	Precision Std	Recall Mean	Recall Std

    #print(file.columns)
    file.to_csv(filename,index=False)

# %%
file
# Out:
#     labeled set size  Dataset Initialization Method Transfer Learning Dataset  \
# 0                  0  abt_buy     Transfer Learning             amazon_google
# 1                100  abt_buy     Transfer Learning             amazon_google
# 2                200  abt_buy     Transfer Learning             amazon_google
# 3                300  abt_buy     Transfer Learning             amazon_google
# 4                400  abt_buy     Transfer Learning             amazon_google
# 5                500  abt_buy     Transfer Learning             amazon_google
# 6                600  abt_buy     Transfer Learning             amazon_google
# 7                700  abt_buy     Transfer Learning             amazon_google
# 8                800  abt_buy     Transfer Learning             amazon_google
# 9                900  abt_buy     Transfer Learning             amazon_google
# 10              1000  abt_buy     Transfer Learning             amazon_google
# 11              1100  abt_buy     Transfer Learning             amazon_google
# 12              1200  abt_buy     Transfer Learning             amazon_google
# 13              1300  abt_buy     Transfer Learning             amazon_google
# 14              1400  abt_buy     Transfer Learning             amazon_google
# 15              1500  abt_buy     Transfer Learning             amazon_google
# 16              1600  abt_buy     Transfer Learning             amazon_google
# 17              1700  abt_buy     Transfer Learning             amazon_google
# 18              1800  abt_buy     Transfer Learning             amazon_google
# 19              1900  abt_buy     Transfer Learning             amazon_google
# 20              2000  abt_buy     Transfer Learning             amazon_google
#
#     AL Runs  Sampling Size Attribute Summarizer Attribute Comparator  \
# 0        20            100               hybrid             abs-diff
# 1        20            100               hybrid             abs-diff
# 2        20            100               hybrid             abs-diff
# 3        20            100               hybrid             abs-diff
# 4        20            100               hybrid             abs-diff
# 5        20            100               hybrid             abs-diff
# 6        20            100               hybrid             abs-diff
# 7        20            100               hybrid             abs-diff
# 8        20            100               hybrid             abs-diff
# 9        20            100               hybrid             abs-diff
# 10       20            100               hybrid             abs-diff
# 11       20            100               hybrid             abs-diff
# 12       20            100               hybrid             abs-diff
# 13       20            100               hybrid             abs-diff
# 14       20            100               hybrid             abs-diff
# 15       20            100               hybrid             abs-diff
# 16       20            100               hybrid             abs-diff
# 17       20            100               hybrid             abs-diff
# 18       20            100               hybrid             abs-diff
# 19       20            100               hybrid             abs-diff
# 20       20            100               hybrid             abs-diff
#
#          Embeddings  Epochs  ...  Run 2: f1  Run 2: precision  Run 2: recall  \
# 0   fasttext.en.bin      20  ...      0.324             0.229          0.550
# 1   fasttext.en.bin      20  ...      0.276             0.168          0.777
# 2   fasttext.en.bin      20  ...      0.324             0.233          0.532
# 3   fasttext.en.bin      20  ...      0.283             0.171          0.827
# 4   fasttext.en.bin      20  ...      0.308             0.284          0.336
# 5   fasttext.en.bin      20  ...      0.426             0.351          0.541
# 6   fasttext.en.bin      20  ...      0.436             0.440          0.432
# 7   fasttext.en.bin      20  ...      0.531             0.522          0.541
# 8   fasttext.en.bin      20  ...      0.567             0.505          0.645
# 9   fasttext.en.bin      20  ...      0.415             0.385          0.450
# 10  fasttext.en.bin      20  ...      0.575             0.477          0.723
# 11  fasttext.en.bin      20  ...      0.491             0.396          0.645
# 12  fasttext.en.bin      20  ...      0.565             0.528          0.609
# 13  fasttext.en.bin      20  ...      0.493             0.487          0.500
# 14  fasttext.en.bin      20  ...      0.564             0.647          0.500
# 15  fasttext.en.bin      20  ...      0.390             0.362          0.423
# 16  fasttext.en.bin      20  ...      0.627             0.593          0.664
# 17  fasttext.en.bin      20  ...      0.644             0.594          0.705
# 18  fasttext.en.bin      20  ...      0.631             0.614          0.650
# 19  fasttext.en.bin      20  ...      0.418             0.462          0.382
# 20  fasttext.en.bin      20  ...      0.590             0.537          0.655
#
#     Run 2: pos_neg_ratio  F1 Mean F1 Std  Precision Mean  Precision Std  \
# 0                      0    0.310  0.019           0.214          0.021
# 1                      6    0.290  0.021           0.188          0.028
# 2                      7    0.318  0.008           0.234          0.001
# 3                      5    0.312  0.041           0.216          0.063
# 4                      5    0.366  0.081           0.347          0.089
# 5                      5    0.408  0.026           0.332          0.027
# 6                      5    0.392  0.062           0.384          0.079
# 7                      4    0.454  0.109           0.392          0.185
# 8                      4    0.537  0.042           0.480          0.035
# 9                      4    0.444  0.040           0.397          0.017
# 10                     4    0.480  0.134           0.428          0.069
# 11                     4    0.506  0.022           0.454          0.083
# 12                     3    0.538  0.037           0.503          0.035
# 13                     3    0.476  0.025           0.462          0.036
# 14                     3    0.556  0.011           0.582          0.091
# 15                     3    0.428  0.054           0.392          0.043
# 16                     3    0.542  0.120           0.516          0.109
# 17                     3    0.616  0.040           0.596          0.004
# 18                     3    0.600  0.044           0.615          0.002
# 19                     3    0.484  0.093           0.502          0.057
# 20                     3    0.594  0.006           0.586          0.070
#
#     Recall Mean  Recall Std
# 0         0.568       0.025
# 1         0.680       0.138
# 2         0.500       0.045
# 3         0.661       0.235
# 4         0.386       0.071
# 5         0.528       0.019
# 6         0.402       0.042
# 7         0.607       0.093
# 8         0.609       0.051
# 9         0.505       0.077
# 10        0.557       0.235
# 11        0.588       0.080
# 12        0.580       0.042
# 13        0.491       0.013
# 14        0.541       0.058
# 15        0.473       0.071
# 16        0.570       0.132
# 17        0.641       0.091
# 18        0.588       0.087
# 19        0.471       0.125
# 20        0.609       0.064
#
# [21 rows x 30 columns]
